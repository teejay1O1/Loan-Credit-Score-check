# %% [markdown]
# # Assignment

# %% [markdown]
# #### Loading Data into the notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',120)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1="C://Users/Tanujdeep/Desktop/Data analytics/aap asigment/loan.xlsx"

# %%
excel= pd.ExcelFile(file1)

# %%
data=excel.parse(excel.sheet_names[0])

# %%
data.shape
# Out:
# (39717, 111)

# %%
data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0    0.1065       162.87     B        B2                       NaN  10+ years
# 1    0.1527        59.83     C        C4                     Ryder   < 1 year
# 2    0.1596        84.33     C        C5                       NaN  10+ years
# 3    0.1349       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4    0.1269        67.79     B        B5  University Medical Group     1 year
#
# ...

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# #### removing data with all values not a number

# %%
data.dropna(axis=1,how="all",inplace=True)
data.shape
# Out:
# (39717, 57)

# %%
data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv      int_rate   installment    annual_inc  \
# count     39717.000000  39717.000000  39717.000000  3.971700e+04
# mean      10397.448868      0.120212    324.561922  6.896893e+04
# std        7128.450439      0.037248    208.874874  6.379377e+04
# min           0.000000      0.054200     15.690000  4.000000e+03
# 25%        5000.000000      0.092500    167.020000  4.040400e+04
# ...

# %%
data.dtypes
# Out:
# id                                     int64
# member_id                              int64
# loan_amnt                              int64
# funded_amnt                            int64
# funded_amnt_inv                      float64
# term                                  object
# int_rate                             float64
# installment                          float64
# grade                                 object
# sub_grade                             object
# emp_title                             object
# emp_length                            object
# home_ownership                        object
# annual_inc                           float64
# verification_status                   object
# issue_d                       datetime64[ns]
# loan_status                           object
# pymnt_plan                            object
# url                                   object
# desc                                  object
# purpose                               object
# ...

# %% [markdown]
# #### Deleting data where all values are zero

# %%
data.drop(columns=["collections_12_mths_ex_med","acc_now_delinq","chargeoff_within_12_mths","delinq_amnt","tax_liens"],inplace=True)
data.shape
# Out:
# (39717, 52)

# %% [markdown]
# #### removing columns which are unimportant for the anaysis

# %%
data.drop(columns=["member_id","url","addr_state","id","zip_code"],inplace=True)
data.shape
# Out:
# (39717, 47)

# %%
data.describe(include="all")
# Out:
#            loan_amnt   funded_amnt  funded_amnt_inv        term      int_rate  \
# count   39717.000000  39717.000000     39717.000000       39717  39717.000000
# unique           NaN           NaN              NaN           2           NaN
# top              NaN           NaN              NaN   36 months           NaN
# freq             NaN           NaN              NaN       29096           NaN
# first            NaN           NaN              NaN         NaN           NaN
# last             NaN           NaN              NaN         NaN           NaN
# mean    11219.443815  10947.713196     10397.448868         NaN      0.120212
# std      7456.670694   7187.238670      7128.450439         NaN      0.037248
# min       500.000000    500.000000         0.000000         NaN      0.054200
# 25%      5500.000000   5400.000000      5000.000000         NaN      0.092500
# 50%     10000.000000   9600.000000      8975.000000         NaN      0.118600
# ...

# %% [markdown]
# #### remove data olumns with reaccuring data for all columns

# %%
data.drop(columns=["pymnt_plan","initial_list_status","application_type"],inplace=True)
data.shape
# Out:
# (39717, 44)
